# %%
import pandas as pd

# %%
df = pd.read_csv('b16001.csv', delimiter='|')

# %%
df
# Out:
#                    GEO_ID  B16001_E001  B16001_M001  B16001_E002  B16001_M002  \
# 0             0400000US53      7364064         2384      5807468        25958
# 1             04000A0US53      7182817         3034      5645933        26016
# 2             04000C0US53      6605037         2287      5147135        24929
# 3             04000C1US53      2798841         8345      2114358        18101
# 4             04000C2US53      3806196         8758      3032777        24133
# 5             040C201US53      6127506        23190      4725251        29652
# 6          0500000US53033      2150551          562      1476348        16897
# 7          0500000US53061       790426          187       610601         9149
# 8        1600000US5363000       721848         2494       547588         9682
# 9   312M600US426605363000       721848         2494       547588         9682
# 10          5001800US5301       736984        10910       508437        11264
# ...
